# %%
from urielplus.urielplus import URIELPlus
u = URIELPlus()
u.integrate_databases()
# Out:
# 2025-02-27 22:36:32,063 - root - INFO - Importing all databases....
# 2025-02-27 22:36:32,065 - root - INFO - Importing updated SAPHON from "saphon_data.csv"....
# 2025-02-27 22:36:34,400 - root - INFO - Updated SAPHON integration complete..
# 2025-02-27 22:36:34,404 - root - INFO - Importing BDPROTO from "bdproto_data.csv"....
# 2025-02-27 22:36:34,411 - root - INFO - Converting ISO 639-3 codes to Glottocodes....
# 2025-02-27 22:36:34,664 - root - INFO - Conversion to Glottocodes complete.
# 2025-02-27 22:36:47,883 - root - INFO - BDPROTO integration complete.
# 2025-02-27 22:36:47,888 - root - INFO - Importing Grambank from "grambank_data.csv"....
# 2025-02-27 22:37:01,431 - root - INFO - Grambank integration complete.
# 2025-02-27 22:37:01,463 - root - INFO - Importing APiCS from "apics_data.csv"....
# 2025-02-27 22:37:04,095 - root - INFO - APiCS integration complete.
# 2025-02-27 22:37:04,100 - root - INFO - Importing eWAVE from "english_dialect_data.csv"....
# 2025-02-27 22:37:11,305 - root - INFO - eWAVE integration complete.
# 2025-02-27 22:37:11,308 - root - INFO - Updating feature data based on inferred features...
# 2025-02-27 22:38:02,051 - root - INFO - Updated feature data based on inferred features complete.
# 2025-02-27 22:38:02,056 - root - INFO - All databases integration complete.

# %%
u.set_aggregation('U')
u.aggregate()
u.knn_imputation()
# Out:
# 2025-02-27 22:38:55,596 - root - INFO - Creating union of data across sources....
# 2025-02-27 22:39:11,425 - root - INFO - Union across sources creation complete.
# 2025-02-27 22:39:11,434 - root - INFO - Starting imputation_interface
# 2025-02-27 22:39:11,435 - root - INFO - Creating union of data across sources....
# 2025-02-27 22:39:25,982 - root - INFO - Union across sources creation complete.
# 2025-02-27 22:39:26,159 - root - INFO - X_train shape: (6128, 800), X_test shape: (2043, 800)
# 2025-02-27 22:39:26,160 - root - INFO - Starting parallel processing for hyperparameter selection
# 2025-02-27 22:45:17,401 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:45:17,402 - root - INFO - Average difference in proportion: 0.11668183382776894
# 2025-02-27 22:45:17,402 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:45:27,099 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:45:27,101 - root - INFO - Average difference in proportion: 0.1222728148903243
# 2025-02-27 22:45:27,101 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:45:27,256 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:45:27,256 - root - INFO - Average difference in proportion: 0.1338490152699289
# 2025-02-27 22:45:27,256 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:45:27,347 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:45:27,351 - root - INFO - Average difference in proportion: 0.12476127877719839
# 2025-02-27 22:45:27,351 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:45:28,282 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:45:28,283 - root - INFO - Average difference in proportion: 0.14154994853825842
# 2025-02-27 22:45:28,283 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:51:38,128 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:51:38,129 - root - INFO - Average difference in proportion: 0.1267071839485514
# 2025-02-27 22:51:38,129 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:52:09,807 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:52:09,807 - root - INFO - Average difference in proportion: 0.1444709596785709
# 2025-02-27 22:52:09,807 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:52:11,114 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:52:11,114 - root - INFO - Average difference in proportion: 0.13897438898685754
# 2025-02-27 22:52:11,114 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:52:11,223 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:52:11,224 - root - INFO - Average difference in proportion: 0.13943529139884672
# 2025-02-27 22:52:11,224 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:52:12,295 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:52:12,301 - root - INFO - Average difference in proportion: 0.14079667702025164
# 2025-02-27 22:52:12,301 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:57:01,462 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:57:01,464 - root - INFO - Average difference in proportion: 0.10565652737743916
# 2025-02-27 22:57:01,464 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:58:36,537 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:58:36,537 - root - INFO - Average difference in proportion: 0.12069321238822572
# 2025-02-27 22:58:36,537 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:58:36,815 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22:58:36,817 - root - INFO - Average difference in proportion: 0.11414553809669344
# 2025-02-27 22:58:36,817 - root - INFO - Smallest difference in proportion: 0.0
# 2025-02-27 22:58:36,988 - root - INFO - Largest difference in proportion: 1.0
# 2025-02-27 22
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/yorky/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/Users/yorky/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yorky/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yorky/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yorky/PycharmProjects/URIELPlusTesting/urielplus/urielplus_imputation.py", line 360, in _cross_val_impute_wrt_hyperparameter
#     avg_metric[key] = np.mean([fold_metrics[i][key] for i in range(n_splits)])
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/yorky/PycharmProjects/URIELPlusTesting/urielplus/urielplus_imputation.py", line 360, in <listcomp>
#     avg_metric[key] = np.mean([fold_metrics[i][key] for i in range(n_splits)])
#                                ~~~~~~~~~~~~~~~^^^^^
# KeyError: 'Q2 (0.02941176470588236)'
# """
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 u.set_aggregation('U')
#       2 u.aggregate()
# ----> 3 u.knn_imputation()
#
# File ~/PycharmProjects/URIELPlusTesting/urielplus/urielplus_imputation.py:806, in URIELPlusImputation.knn_imputation(self)
#     804 else:
#     805     eval_metric = "rmse"
# --> 806 _ = self.imputation_interface(strategy="knn", save_as_npz=True, test_quality=True, eval_metric=eval_metric, hyperparameter_range=(3, 6, 9, 12, 15))
#
# File ~/PycharmProjects/URIELPlusTesting/urielplus/urielplus_imputation.py:718, in URIELPlusImputation.imputation_interface(self, csv_path, strategy, file_path_to_save_npz, feature_prefixes, eval_metric, hyperparameter_range, test_quality, return_csv, save_as_npz)
#     716 X, feature_types = self._preprocess_data(combined_df_u, feature_prefixes)
#     717 if strategy in ["knn", "softimpute"] and hyperparameter_range is not None:
# --> 718     imputed = self._hyperparameter_imputation(X=X, strategy=strategy,
#     719                                         feature_types=feature_types,
#     720                                         hyperparameter_range=hyperparameter_range,
#     721                                         eval_metric=eval_metric,
#     722                                         test_quality=test_quality,
#     723                                         file_path_to_save_npz=file_path_to_save_npz)
#     724 elif strategy == "midas":
#     725     data_in, bin_vars = self._preprocess_midas(combined_df_u)
#
# File ~/PycharmProjects/URIELPlusTesting/urielplus/urielplus_imputation.py:590, in URIELPlusImputation._hyperparameter_imputation(self, X, strategy, feature_types, hyperparameter_range, eval_metric, test_quality, file_path_to_save_npz)
#     587 X_train, X_test = train_test_split(X, test_size=0.25, random_state=0)
#     588 logging.info(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
# --> 590 best_hyperparameter = self._choose_hyperparameter_cv(X_train, X_test,
#     591                                             strategy=strategy,
#     592                                             feature_types=feature_types,
#     593                                             missing_rate=0.2,
#     594                                             hyperparameter_range=hyperparameter_range,
#     595                                             eval_metric=eval_metric)
#     597 imputer_class = KNNImputer if strategy == "knn" else SoftImpute
#     598 if test_quality:
#
# File ~/PycharmProjects/URIELPlusTesting/urielplus/urielplus_imputation.py:374, in URIELPlusImputation._choose_hyperparameter_cv(self, X_train, X_test, strategy, feature_types, missing_rate, hyperparameter_range, eval_metric, n_splits)
#     369 def _choose_hyperparameter_cv(self, X_train, X_test, strategy,
#     370                       feature_types, missing_rate=0.2,
#     371                       hyperparameter_range=range(3, 21, 3),
#     372                       eval_metric="f1", n_splits=10):
#     373     logging.info("Starting parallel processing for hyperparameter selection")
# --> 374     results = Parallel(n_jobs=-1)(delayed(self._cross_val_impute_wrt_hyperparameter)(X_train, strategy, feature_types, hyperparameter, eval_metric, n_splits, missing_rate) for hyperparameter in hyperparameter_range)
#     375     """
#     376         Selects the best hyperparameter for an imputation strategy using k-fold cross-validation.
#     377
#    (...)
#     392             int or float: The best hyperparameter for the specified strategy based on the evaluation metric.
#     393     """
#     394     logging.info("Completed parallel processing for hyperparameter selection")
#
# File ~/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File ~/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File ~/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File ~/PycharmProjects/urielplus/.venv/lib/python3.11/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# KeyError: 'Q2 (0.02941176470588236)'

# %%
iso_code_langs = ['amh', 'eng', 'fra', 'hau', 'ibo', 'lin', 'lug', 'orm', 'pcm', 'run', 'sna', 'som', 'swa', 'tir', 'xho', 'yor']
glottocode_langs = ['amha1245', 'stan1293', 'stan1290', 'haus1257', 'nucl1417', 'ling1263', 'gand1255', 'west2721', 'nige1257', 'rund1242', 'shon1251', 'soma1255', 'swah1253', 'tigr1271', 'xhos1239', 'yoru1245']
